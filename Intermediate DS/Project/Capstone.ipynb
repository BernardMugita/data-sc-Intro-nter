# %%
# importing the relevant libraries

import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;
import seaborn as sns;
from datetime import datetime;
from datetime import date

# %% [markdown]
# # Exploratory analysis and data cleaning

# %%
drivers = pd.read_csv(r'/home/jeromemugita/Documents/Code/DataScience/Intermediate DS/Project/archive/drivers.csv')
display(drivers.head(n=5))
# Out:
#    driverId   driverRef number code  forename     surname         dob
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07  \
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
drivers.isna().sum()
# Out:
# driverId       0
# driverRef      0
# number         0
# code           0
# forename       0
# surname        0
# dob            0
# nationality    0
# url            0
# dtype: int64

# %%
drivers.drop(columns=['url', 'nationality', 'forename', 'surname', 'dob', 'number'], inplace=True)
drivers
# Out:
#      driverId        driverRef code
# 0           1         hamilton  HAM
# 1           2         heidfeld  HEI
# 2           3          rosberg  ROS
# 3           4           alonso  ALO
# 4           5       kovalainen  KOV
# ..        ...              ...  ...
# 852       854  mick_schumacher  MSC
# 853       855             zhou  ZHO
# 854       856         de_vries  DEV
# 855       857          piastri  PIA
# 856       858         sargeant  SAR
#
# [857 rows x 3 columns]

# %%
# drivers['code'][49] = drivers['code'][49].replace('\\N', 'VER')

for index, row in drivers.iterrows():
    if row['driverId'] == 50:
        drivers.at[index, 'code'] = 'VER'
        
drivers
# Out:
#      driverId        driverRef code
# 0           1         hamilton  HAM
# 1           2         heidfeld  HEI
# 2           3          rosberg  ROS
# 3           4           alonso  ALO
# 4           5       kovalainen  KOV
# ..        ...              ...  ...
# 852       854  mick_schumacher  MSC
# 853       855             zhou  ZHO
# 854       856         de_vries  DEV
# 855       857          piastri  PIA
# 856       858         sargeant  SAR
#
# [857 rows x 3 columns]

# %%
selected_drivers = ['michael_schumacher', 'verstappen', 'hamilton', 'vettel']
selected_drivers_data = drivers[drivers['driverRef'].isin(selected_drivers)]
selected_drivers_data
# Out:
#     driverId           driverRef code
# 0          1            hamilton  HAM
# 19        20              vettel  VET
# 29        30  michael_schumacher  MSC
# 49        50          verstappen  VER

# %%
df_drivers = pd.DataFrame(selected_drivers_data)
df_drivers
# Out:
#     driverId           driverRef code
# 0          1            hamilton  HAM
# 19        20              vettel  VET
# 29        30  michael_schumacher  MSC
# 49        50          verstappen  VER

# %%
pit_stops = pd.read_csv(r'/home/jeromemugita/Documents/Code/DataScience/Intermediate DS/Project/archive/pit_stops.csv')
display(pit_stops.head(n=5))
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
pit_stops.shape
# Out:
# (9634, 7)

# %%
pit_stops.isnull().sum()
# Out:
# raceId          0
# driverId        0
# stop            0
# lap             0
# time            0
# duration        0
# milliseconds    0
# dtype: int64

# %%
pit_stops.dtypes
# Out:
# raceId           int64
# driverId         int64
# stop             int64
# lap              int64
# time            object
# duration        object
# milliseconds     int64
# dtype: object

# %%
pit_stops[pit_stops['driverId'] == 50]
# Out:
# Empty DataFrame
# Columns: [raceId, driverId, stop, lap, time, duration, milliseconds]
# Index: []

# %%
pit_stops = pit_stops[pit_stops['raceId'] > 1091]
pit_stops
# Out:
#       raceId  driverId  stop  lap      time  duration  milliseconds
# 9458    1092       842     1    1  14:06:24    41.319         41319
# 9459    1092       830     1    2  14:08:39  6:27.399        387399
# 9460    1092       844     1    2  14:08:41  6:29.973        389973
# 9461    1092       815     1    2  14:08:44  6:32.517        392517
# 9462    1092       839     1    2  14:08:46  6:33.601        393601
# ...      ...       ...   ...  ...       ...       ...           ...
# 9629    1096       849     2   38  18:02:50    25.174         25174
# 9630    1096       840     2   40  18:04:44    21.802         21802
# 9631    1096       839     2   41  18:06:09    21.734         21734
# 9632    1096       846     2   42  18:07:36    21.559         21559
# 9633    1096       855     2   44  18:11:10    23.159         23159
#
# [176 rows x 7 columns]

# %%
# driver_ids = [1, 20, 30, 50]
# df_pitstops = pd.DataFrame(pit_stops[pit_stops['driverId'].isin(driver_ids)])

# df_pitstops['driverId'].unique()

# %%
results = pd.read_csv(r'/home/jeromemugita/Documents/Code/DataScience/Intermediate DS/Project/archive/results.csv')
display(results.head(n=5))
# Out:
#    resultId  raceId  driverId  constructorId number  grid position
# 0         1      18         1              1     22     1        1  \
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds
# 0            1              1    10.0    58  1:34:50.616      5690616  \
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %%
results.shape
# Out:
# (25840, 18)

# %%
results.sort_values(by='time', ascending=True)
# Out:
#        resultId  raceId  driverId  constructorId number  grid position
# 15810     15811     640       238            200     25     6        2  \
# 2517       2518     139        30              6      1     1        2
# 9433       9434     405        95              3      5     3        2
# 11427     11428     479       177              3      6     6        2
# 16310     16311     663       358            180      4     1        2
# ...         ...     ...       ...            ...    ...   ...      ...
# 9998       9999     427       105              6     27     6        2
# 9996       9997     426        95              3      5     8       \N
# 9995       9996     426       172             27     26    15       \N
# 10004     10005     427        77             21     17    17        8
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  laps    time milliseconds
# ...

# %%
results.isna().sum()
# Out:
# resultId           0
# raceId             0
# driverId           0
# constructorId      0
# number             0
# grid               0
# position           0
# positionText       0
# positionOrder      0
# points             0
# laps               0
# time               0
# milliseconds       0
# fastestLap         0
# rank               0
# fastestLapTime     0
# fastestLapSpeed    0
# statusId           0
# dtype: int64

# %%
results = results[results['raceId'] > 1091]
results
# Out:
#        resultId  raceId  driverId  constructorId number  grid position
# 25740     25746    1092       830              9      1     1        1  \
# 25741     25747    1092       815              9     11     4        2
# 25742     25748    1092       844              6     16     2        3
# 25743     25749    1092       839            214     31     5        4
# 25744     25750    1092         1            131     44     6        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  laps         time milliseconds
# ...

# %%
# driver_ids = [1, 20, 30, 50]
# df_results = pd.DataFrame(results[results['driverId'].isin(driver_ids)])
# df_results

# %%
# df_drivers['code'][49] = df_drivers['code'][49].replace('\\N', 'VER')
# df_drivers

# %%
merger_one = results.merge(pit_stops, on='driverId', how='left', suffixes=['_race_result', '_in_pit'])
merger_one.columns
# Out:
# Index(['resultId', 'raceId_race_result', 'driverId', 'constructorId', 'number',
#        'grid', 'position', 'positionText', 'positionOrder', 'points', 'laps',
#        'time_race_result', 'milliseconds_race_result', 'fastestLap', 'rank',
#        'fastestLapTime', 'fastestLapSpeed', 'statusId', 'raceId_in_pit',
#        'stop', 'lap', 'time_in_pit', 'duration', 'milliseconds_in_pit'],
#       dtype='object')

# %%
merger_one.isna().sum()
# Out:
# resultId                    0
# raceId_race_result          0
# driverId                    0
# constructorId               0
# number                      0
# grid                        0
# position                    0
# positionText                0
# positionOrder               0
# points                      0
# laps                        0
# time_race_result            0
# milliseconds_race_result    0
# fastestLap                  0
# rank                        0
# fastestLapTime              0
# fastestLapSpeed             0
# statusId                    0
# raceId_in_pit               0
# stop                        0
# lap                         0
# time_in_pit                 0
# duration                    0
# milliseconds_in_pit         0
# dtype: int64

# %%
merger_one.dropna(subset=['raceId_in_pit', 'stop', 'lap', 'time_in_pit', 'duration', 'milliseconds_in_pit'], inplace=True)

# %%
merger_one.isna().sum()
# Out:
# resultId                    0
# raceId_race_result          0
# driverId                    0
# constructorId               0
# number                      0
# grid                        0
# position                    0
# positionText                0
# positionOrder               0
# points                      0
# laps                        0
# time_race_result            0
# milliseconds_race_result    0
# fastestLap                  0
# rank                        0
# fastestLapTime              0
# fastestLapSpeed             0
# statusId                    0
# raceId_in_pit               0
# stop                        0
# lap                         0
# time_in_pit                 0
# duration                    0
# milliseconds_in_pit         0
# dtype: int64

# %%
merger_one.dtypes
# Out:
# resultId                      int64
# raceId_race_result            int64
# driverId                      int64
# constructorId                 int64
# number                       object
# grid                          int64
# position                     object
# positionText                 object
# positionOrder                 int64
# points                      float64
# laps                          int64
# time_race_result             object
# milliseconds_race_result     object
# fastestLap                   object
# rank                         object
# fastestLapTime               object
# fastestLapSpeed              object
# statusId                      int64
# raceId_in_pit                 int64
# stop                          int64
# lap                           int64
# time_in_pit                  object
# duration                     object
# milliseconds_in_pit           int64
# dtype: object

# %%
merger_one.drop(columns=['number', 'grid', 'positionText', 'positionOrder', 'points', 'statusId', 'raceId_in_pit'], inplace=True)
merger_one
# Out:
#      resultId  raceId_race_result  driverId  constructorId position  laps
# 0       25746                1092       830              9        1    28  \
# 1       25746                1092       830              9        1    28
# 2       25746                1092       830              9        1    28
# 3       25746                1092       830              9        1    28
# 4       25746                1092       830              9        1    28
# ..        ...                 ...       ...            ...      ...   ...
# 875     25845                1096         4            214       \N    27
# 876     25845                1096         4            214       \N    27
# 877     25845                1096         4            214       \N    27
# 878     25845                1096         4            214       \N    27
# 879     25845                1096         4            214       \N    27
#
#     time_race_result milliseconds_race_result fastestLap rank fastestLapTime
# ...

# %%
merger_one['raceId_race_result'].unique().max()
# Out:
# 1096

# %%
positions = ['1', '2', '3']
merger_one[merger_one['position'].isin(positions)]
# Out:
#      resultId  raceId_race_result  driverId  constructorId position  laps
# 0       25746                1092       830              9        1    28  \
# 1       25746                1092       830              9        1    28
# 2       25746                1092       830              9        1    28
# 3       25746                1092       830              9        1    28
# 4       25746                1092       830              9        1    28
# ..        ...                 ...       ...            ...      ...   ...
# 726     25828                1096       815              9        3    58
# 727     25828                1096       815              9        3    58
# 728     25828                1096       815              9        3    58
# 729     25828                1096       815              9        3    58
# 730     25828                1096       815              9        3    58
#
#     time_race_result milliseconds_race_result fastestLap rank fastestLapTime
# ...

# %%
merger_one.shape
# Out:
# (880, 17)

# %%
merger_one.tail(30)
# Out:
#      resultId  raceId_race_result  driverId  constructorId position  laps
# 850     25842                1096       825            210       17    57  \
# 851     25843                1096         1            131       18    55
# 852     25843                1096         1            131       18    55
# 853     25843                1096         1            131       18    55
# 854     25843                1096         1            131       18    55
# 855     25843                1096         1            131       18    55
# 856     25843                1096         1            131       18    55
# 857     25843                1096         1            131       18    55
# 858     25843                1096         1            131       18    55
# 859     25844                1096       849              3       19    55
# 860     25844                1096       849              3       19    55
# 861     25844                1096       849              3       19    55
# ...

# %%
merger_one['time_race_result'].replace('\\N', pd.NaT, inplace=True)
merger_one['milliseconds_race_result'].replace('\\N', pd.NaT, inplace=True)
merger_one
# Out:
#      resultId  raceId_race_result  driverId  constructorId position  laps
# 0       25746                1092       830              9        1    28  \
# 1       25746                1092       830              9        1    28
# 2       25746                1092       830              9        1    28
# 3       25746                1092       830              9        1    28
# 4       25746                1092       830              9        1    28
# ..        ...                 ...       ...            ...      ...   ...
# 875     25845                1096         4            214       \N    27
# 876     25845                1096         4            214       \N    27
# 877     25845                1096         4            214       \N    27
# 878     25845                1096         4            214       \N    27
# 879     25845                1096         4            214       \N    27
#
#     time_race_result milliseconds_race_result fastestLap rank fastestLapTime
# ...

# %%
merger_one.dropna(subset=['time_race_result', 'milliseconds_race_result'], inplace=True)
merger_one
# Out:
#      resultId  raceId_race_result  driverId  constructorId position  laps
# 0       25746                1092       830              9        1    28  \
# 1       25746                1092       830              9        1    28
# 2       25746                1092       830              9        1    28
# 3       25746                1092       830              9        1    28
# 4       25746                1092       830              9        1    28
# ..        ...                 ...       ...            ...      ...   ...
# 796     25836                1096       852            213       11    58
# 797     25836                1096       852            213       11    58
# 798     25836                1096       852            213       11    58
# 799     25836                1096       852            213       11    58
# 800     25836                1096       852            213       11    58
#
#     time_race_result milliseconds_race_result fastestLap rank fastestLapTime
# ...

# %%
merger_one['milliseconds_race_result'] = merger_one['milliseconds_race_result'].astype(str)
merger_one['position'] = merger_one['position'].astype(int)
merger_one['fastestLap'] = merger_one['fastestLap'].astype(int)
merger_one['rank'] = merger_one['rank'].astype(int)

# %%
merger_one.dtypes
# Out:
# resultId                             int64
# raceId_race_result                   int64
# driverId                             int64
# constructorId                        int64
# position                             int64
# laps                                 int64
# time_race_result            datetime64[ns]
# milliseconds_race_result            object
# fastestLap                           int64
# rank                                 int64
# fastestLapTime                      object
# fastestLapSpeed                     object
# stop                                 int64
# lap                                  int64
# time_in_pit                         object
# duration                            object
# milliseconds_in_pit                  int64
# dtype: object

# %%
milliseconds = merger_one['time_race_result']

def convert_to_datetime(race_time_str):
    try:
        hours, minutes, seconds = race_time_str.split(':')
        total_seconds = int(hours) * 3600 + int(minutes) * 60 + float(seconds)
        return pd.Timestamp.min + pd.Timedelta(seconds=total_seconds)
    except ValueError:
        return pd.NaT

# Convert the column to datetime using the custom function
merger_one['time_race_result'] = milliseconds.apply(convert_to_datetime)

# %%
merger_one.isna().sum()
# Out:
# resultId                      0
# raceId_race_result            0
# driverId                      0
# constructorId                 0
# position                      0
# laps                          0
# time_race_result            562
# milliseconds_race_result      0
# fastestLap                    0
# rank                          0
# fastestLapTime                0
# fastestLapSpeed               0
# stop                          0
# lap                           0
# time_in_pit                   0
# duration                      0
# milliseconds_in_pit           0
# dtype: int64

# %%
merger_one.head(40)
# Out:
#     resultId  raceId_race_result  driverId  constructorId  position  laps
# 0      25746                1092       830              9         1    28  \
# 1      25746                1092       830              9         1    28
# 2      25746                1092       830              9         1    28
# 3      25746                1092       830              9         1    28
# 4      25746                1092       830              9         1    28
# 5      25746                1092       830              9         1    28
# 6      25746                1092       830              9         1    28
# 7      25746                1092       830              9         1    28
# 8      25746                1092       830              9         1    28
# 9      25747                1092       815              9         2    28
# 10     25747                1092       815              9         2    28
# 11     25747                1092       815              9         2    28
# ...
