# %% [markdown]
# #### Template For Linear Regression

# %% [markdown]
# #### 1. Statement of Problem

# %% [markdown]
# To predict the weather in the weather dataset

# %% [markdown]
# #### 2. Import Relevant Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy
#from imblearn.over_sampling import RandomOverSampler
from sklearn.preprocessing import  StandardScaler
import seaborn as sns
from sklearn import metrics
from sklearn.linear_model import LinearRegression
#import tensorflow as tf

# %% [markdown]
# #### 3a. Importing the dataset

# %%
####  OR

# %% [markdown]
# #### 3b. Read data onto Jupyter Notebook

# %%
weather_dataset = pd.read_csv(r'/home/jeromemugita/Downloads/weather.csv')

# %% [markdown]
# #### 4. View Summary of Data

# %%
df = weather_dataset.copy()

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir
# 0      8.0     24.3       0.0          3.4       6.3          NW  \
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm
# 0           30.0         SW         NW           6.0  ...           29  \
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday
# ...

# %%
df.shape
# Out:
# (366, 22)

# %%
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine
# count  366.000000  366.000000  366.000000   366.000000  363.000000  \
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm
# count     364.000000    359.000000    366.000000   366.000000   366.000000  \
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
df.describe().T
# Out:
#                count         mean        std    min       25%      50%
# MinTemp        366.0     7.265574   6.025800   -5.3     2.300     7.45  \
# MaxTemp        366.0    20.550273   6.690516    7.6    15.025    19.65
# Rainfall       366.0     1.428415   4.225800    0.0     0.000     0.00
# Evaporation    366.0     4.521858   2.669383    0.2     2.200     4.20
# Sunshine       363.0     7.909366   3.481517    0.0     5.950     8.60
# WindGustSpeed  364.0    39.840659  13.059807   13.0    31.000    39.00
# WindSpeed9am   359.0     9.651811   7.951929    0.0     6.000     7.00
# WindSpeed3pm   366.0    17.986339   8.856997    0.0    11.000    17.00
# Humidity9am    366.0    72.035519  13.137058   36.0    64.000    72.00
# Humidity3pm    366.0    44.519126  16.850947   13.0    32.250    43.00
# Pressure9am    366.0  1019.709016   6.686212  996.5  1015.350  1020.15
# Pressure3pm    366.0  1016.810383   6.469422  996.8  1012.800  1017.40
# ...

# %%
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
#Checking the data types :
df.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
# Identifying the unique number of values in the dataset
df.nunique()
# Out:
# MinTemp          180
# MaxTemp          187
# Rainfall          47
# Evaporation       55
# Sunshine         114
# WindGustDir       16
# WindGustSpeed     35
# WindDir9am        16
# WindDir3pm        16
# WindSpeed9am      22
# WindSpeed3pm      26
# Humidity9am       60
# Humidity3pm       74
# Pressure9am      190
# Pressure3pm      193
# Cloud9am           9
# Cloud3pm           9
# Temp9am          178
# Temp3pm          200
# RainToday          2
# RISK_MM           47
# RainTomorrow       2
# dtype: int64

# %%
# Check for missing values
df.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
# See rows with missing values
df[df.isnull().any(axis=1)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir
# 113     12.7     28.6       6.6          3.2       8.6           W  \
# 118     11.7     27.6       0.0          7.8       8.1           W
# 127     10.8     29.2       0.0          8.4       7.5           E
# 138     12.5     29.9       0.0          5.8      10.7          NW
# 140     11.5     29.3       0.0          5.2       8.0          NW
# 174      7.5     19.0       0.0          4.0       6.8         ENE
# 176      5.0     20.9       0.0          2.0       8.9         WNW
# 180     -2.1     13.8       0.2          1.8       9.5         NNW
# 189     -0.2     18.1       0.0          4.4       9.4          NW
# 193      9.4     19.2       0.0          2.2       7.7         NaN
# 195      2.2     18.6       0.0          2.0       9.2         NNW
# 200     -2.7     18.1       0.0          2.2       9.3           W
# 208      4.9     18.1       5.2          1.2       8.5         NNW
# ...

# %% [markdown]
# Solving for missing values

# %%
df_sunshine = df['Sunshine'].fillna(7.909366)
df.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
df['Sunshine'] = df_sunshine.copy()
df.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          0
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
df_windGustDir = df['WindGustDir'].ffill(axis = 0)
df['WindGustDir'] = df_windGustDir.copy()
df.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          0
# WindGustDir       0
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
df_WindGustSpeed = df['WindGustSpeed'].fillna(39.840659)
df['WindGustSpeed'] = df_WindGustSpeed.copy()
df.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          0
# WindGustDir       0
# WindGustSpeed     0
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
df_WindDir9am = df['WindDir9am'].fillna(9.651811)
df['WindDir9am'] = df_WindDir9am.copy()
df.isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       1
# WindSpeed9am     7
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df_WindDir3pm = df['WindDir3pm'].ffill(axis=0)
df['WindDir3pm'] = df_WindDir3pm.copy()
df.isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     7
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df_WindSpeed9am = df['WindSpeed9am'].fillna(17.986339)
df['WindSpeed9am'] = df_WindSpeed9am .copy()
df.isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir
# 0      8.0     24.3       0.0          3.4       6.3          NW  \
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm
# 0           30.0         SW         NW           6.0  ...           29  \
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday
# ...

# %%
# Replace value for RainToday 1 for 'Yes' and 2 for 'No'

df['RainToday'].replace({'Yes' : 1, 'No': 2}, inplace=True)

# %%
print(df['RainToday'])
# Out:
# 0      2
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 361    2
# 362    2
# 363    2
# 364    2
# 365    2
# Name: RainToday, Length: 366, dtype: int64

# %%
# Replace value for RainTomorrow 1 for 'Yes' and 2 for 'No'

df['RainTomorrow'].replace({'Yes' : 1, 'No': 2}, inplace=True)

# %%
df['RainTomorrow']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      2
#       ..
# 361    2
# 362    2
# 363    2
# 364    2
# 365    2
# Name: RainTomorrow, Length: 366, dtype: int64

# %%
# Converting values for WindGustDirection with integers 1 to 16 representing the 16 compass points counting
# clockwise from North (N as 1). 

df['WindGustDir'].replace({'N' : 1, 'NNE': 2, 'NE': 3, 'ENE': 4, 'E': 5, 'ESE' : 6, 'SE': 7, 'SSE': 8, 'S': 9,
                          'SSW' : 10, 'SW': 11, 'WSW': 12, 'W': 13, 'WNW' : 14, 'NW': 15, 'NNW': 16}, inplace=True)
df['WindGustDir']
# Out:
# 0      15
# 1       4
# 2      15
# 3      15
# 4       8
#        ..
# 361    16
# 362     1
# 363     6
# 364    15
# 365    15
# Name: WindGustDir, Length: 366, dtype: int64

# %%
# Converting values for Wind Direction at 9am with integers 1 to 16 representing the 16 compass points counting
# clockwise from North (N as 1). 

df['WindDir9am'].replace({'N' : 1, 'NNE': 2, 'NE': 3, 'ENE': 4, 'E': 5, 'ESE' : 6, 'SE': 7, 'SSE': 8, 'S': 9,
                          'SSW' : 10, 'SW': 11, 'WSW': 12, 'W': 13, 'WNW' : 14, 'NW': 15, 'NNW': 16}, inplace=True)
df['WindDir9am']
# Out:
# 0      11.0
# 1       5.0
# 2       1.0
# 3      14.0
# 4       8.0
#        ...
# 361     8.0
# 362    16.0
# 363     4.0
# 364    10.0
# 365    15.0
# Name: WindDir9am, Length: 366, dtype: float64

# %%
# Converting values for Wind direction at 3pm with integers 1 to 16 representing the 16 compass points counting
# clockwise from North (N as 1). 

df['WindDir3pm'].replace({'N' : 1, 'NNE': 2, 'NE': 3, 'ENE': 4, 'E': 5, 'ESE' : 6, 'SE': 7, 'SSE': 8, 'S': 9,
                          'SSW' : 10, 'SW': 11, 'WSW': 12, 'W': 13, 'WNW' : 14, 'NW': 15, 'NNW': 16}, inplace=True)
df['WindDir3pm']
# Out:
# 0      15
# 1      13
# 2       2
# 3      13
# 4       6
#        ..
# 361    15
# 362    16
# 363     4
# 364    14
# 365    14
# Name: WindDir3pm, Length: 366, dtype: int64

# %%
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir
# 0        8.0     24.3       0.0          3.4       6.3           15  \
# 1       14.0     26.9       3.6          4.4       9.7            4
# 2       13.7     23.4       3.6          5.8       3.3           15
# 3       13.3     15.5      39.8          7.2       9.1           15
# 4        7.6     16.1       2.8          5.6      10.6            8
# ..       ...      ...       ...          ...       ...          ...
# 361      9.0     30.7       0.0          7.6      12.1           16
# 362      7.1     28.4       0.0         11.6      12.7            1
# 363     12.5     19.9       0.0          8.4       5.3            6
# 364     12.5     26.9       0.0          5.0       7.1           15
# 365     12.3     30.2       0.0          6.0      12.6           15
#
#      WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity3pm
# ...

# %% [markdown]
# #### Linear Regression

# %%
# Finding out the correlation between the features
corr = df.corr()
corr
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine
# MinTemp        1.000000  0.752471  0.201939     0.649930  0.035531  \
# MaxTemp        0.752471  1.000000 -0.073560     0.690026  0.451395
# Rainfall       0.201939 -0.073560  1.000000    -0.007293 -0.149326
# Evaporation    0.649930  0.690026 -0.007293     1.000000  0.316942
# Sunshine       0.035531  0.451395 -0.149326     0.316942  1.000000
# WindGustDir   -0.194109 -0.177602  0.067346    -0.150277 -0.019586
# WindGustSpeed  0.217224  0.109415  0.096160     0.287709  0.095676
# WindDir9am    -0.092434 -0.154785  0.082244    -0.151880  0.011033
# WindDir3pm    -0.144985  0.002310 -0.052418    -0.037459  0.162311
# WindSpeed9am   0.117961 -0.211588  0.214400     0.062252 -0.069382
# WindSpeed3pm  -0.065922 -0.167873  0.056008     0.048601  0.072494
# Humidity9am   -0.207897 -0.359602  0.150109    -0.519587 -0.497692
# Humidity3pm   -0.040709 -0.533327  0.289013    -0.391780 -0.755186
# ...

# %%
# Spliting target variable and independent variables

X = df.iloc[:, :-1]

X = df.drop(['MinTemp'], axis = 1)
y = df['MaxTemp']

# %%
# We split the data into training and testing sets.
# We will train the model with 80% of the samples,(0.8)
# and test with the remaining 20%.(0.2)

# %%
# Splitting to training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 5)

# %%
print(X_train.shape)     # => X : For training : inputs or features
print(X_test.shape)
print(y_train.shape)     # => y : For training : Output or label
print(y_test.shape)
# Out:
# (292, 21)
# (74, 21)
# (292,)
# (74,)

# %% [markdown]
# ##### a. Training the model

# %%
# Import library for Linear Regression
from sklearn.linear_model import LinearRegression

# Create a Linear regressor
lm = LinearRegression()

# Train the model using the training sets 
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ##### Results:

# %%
# Value of y intercept
lm.intercept_
# Out:
# 2.1671553440683056e-13

# %%
#Converting the coefficient values to a dataframe
coefficients = pd.DataFrame([X_train.columns,lm.coef_]).T
coefficients = coefficients.rename(columns={0: 'Attribute', 1: 'Coefficients'})
coefficients
# Out:
#         Attribute Coefficients
# 0         MaxTemp          1.0
# 1        Rainfall          0.0
# 2     Evaporation          0.0
# 3        Sunshine          0.0
# 4     WindGustDir          0.0
# 5   WindGustSpeed          0.0
# 6      WindDir9am          0.0
# 7      WindDir3pm         -0.0
# 8    WindSpeed9am          0.0
# 9    WindSpeed3pm         -0.0
# 10    Humidity9am         -0.0
# 11    Humidity3pm          0.0
# 12    Pressure9am          0.0
# 13    Pressure3pm         -0.0
# 14       Cloud9am         -0.0
# 15       Cloud3pm         -0.0
# 16        Temp9am          0.0
# 17        Temp3pm         -0.0
# 18      RainToday         -0.0
# 19        RISK_MM         -0.0
# 20   RainTomorrow         -0.0

# %% [markdown]
# #### b.Model Evaluation

# %%
# Model prediction on train data
y_pred = lm.predict(X_train)

# %%
# Model Evaluation
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# R^2: 1.0
# Adjusted R^2: 1.0
# MAE: 4.346599184080408e-15
# MSE: 3.5025964507501434e-29
# RMSE: 5.91827377767381e-15

# %%
print(f'Train Accuracy {round(lm.score(X_train, y_train)* 100,2)}%')
print(f'Test Accuracy {round(lm.score(X_test, y_test)* 100,2)}%')
# Out:
# Train Accuracy 100.0%
# Test Accuracy 100.0%

# %% [markdown]
# #### Notes:

# %% [raw]
# 𝑅^2 : It is a measure of the linear relationship between X and Y. It is interpreted as the proportion of the variance in the dependent variable that is predictable from the independent variable.
#
# Adjusted 𝑅^2 :The adjusted R-squared compares the explanatory power of regression models that contain different numbers of predictors.
#
# MAE : It is the mean of the absolute value of the errors. It measures the difference between two continuous variables, here actual and predicted values of y.
#
# MSE: The mean square error (MSE) is just like the MAE, but squares the difference before summing them all instead of using the absolute value.
#
# RMSE: The mean square error (MSE) is just like the MAE, but squares the difference before summing them all instead of using the absolute value.

# %% [markdown]
# # Prediction
