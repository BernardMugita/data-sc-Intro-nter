# %% [markdown]
# #### 6.0 Decision Trees

# %% [raw]
# 1. A Decision Tree is a branching flow diagram or tree chart which helps in making decisions
#    based on previous experience.
#
# 2. Decision trees are  effective techniques, particularly for classification problems.
#
# 3. A decision tree comprises of the following :
#
# a. A target variable and its initial distribution.
#
# b. Root node:
# This is the node that begins the splitting process by finding the variable that best splits the target variable.
#
# c. Node purity:
# Decision nodes are typically impure, or a mixture of both classes of the target variable.
# Pure nodes are those that have one class — hence the term pure.
#
#
# d. Decision nodes:
# These are subsequent or intermediate nodes, where the target variable is again split further
# by other variables.
#
# e.Leaf nodes:
# Leaf nodes or terminal nodes are pure nodes, and are used for making a prediction of
# either a numerical or class.

# %%
# Example 6.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier         #  Decision Tree Classifier
from sklearn.model_selection import train_test_split    #  train_test_split function
from sklearn import metrics                             #  for accuracy calculation

# %%
# Incase you get an error in importing libraries => !pip install

# %%
diabetes = pd.read_csv(r'C:\Users\user\Downloads\diabetes.csv')
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df = diabetes.copy()

# %%
features = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']

# %%
# Select the features (X) and label (y) : 
X = df[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']]
y = df['Outcome']

# %%
# Split into Train and Test :
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0) # 80% training and 20% test

# %%
# Create Decision Tree classifier object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifier
clf  = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf .predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7857142857142857

# %%
# Do with 70% accuracy...   => Homework ********

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(clf,feature_names=features)
plt.savefig
# Out:
# <function matplotlib.pyplot.savefig(*args, **kwargs)>

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.40579044117647056, 0.9642857142857143, 'x[1] <= 123.5\ngini = 0.461\nsamples = 614\nvalue = [393, 221]'),
#  Text(0.14767156862745098, 0.8928571428571429, 'x[7] <= 28.5\ngini = 0.301\nsamples = 352\nvalue = [287, 65]'),
#  Text(0.05392156862745098, 0.8214285714285714, 'x[5] <= 30.95\ngini = 0.162\nsamples = 202\nvalue = [184, 18]'),
#  Text(0.029411764705882353, 0.75, 'x[0] <= 7.0\ngini = 0.036\nsamples = 110\nvalue = [108, 2]'),
#  Text(0.0196078431372549, 0.6785714285714286, 'x[6] <= 0.672\ngini = 0.018\nsamples = 109\nvalue = [108, 1]'),
#  Text(0.00980392156862745, 0.6071428571428571, 'gini = 0.0\nsamples = 99\nvalue = [99, 0]'),
#  Text(0.029411764705882353, 0.6071428571428571, 'x[6] <= 0.697\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.0196078431372549, 0.5357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0392156862745098, 0.5357142857142857, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
# ...

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(clf,
               feature_names = features, 
               class_names='Outcome',
               rounded=True, 
               filled = True);
plt.savefig
# Out:
# <function matplotlib.pyplot.savefig(*args, **kwargs)>
