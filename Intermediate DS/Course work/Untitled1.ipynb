# %%
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt

# %%
norway_data = pd.read_csv(r'/home/jeromemugita/Downloads/norway.csv')
norway_data
# Out:
#     Year  Consumer price index (2010 = 100)
# 0   1970                          13.932898  \
# 1   1971                          14.804876
# 2   1972                          15.873753
# 3   1973                          17.055142
# 4   1974                          18.660801
# 5   1975                          20.845434
# 6   1976                          22.758161
# 7   1977                          24.816217
# 8   1978                          26.839112
# 9   1979                          28.116607
# 10  1980                          31.180251
# 11  1981                          35.432316
# 12  1982                          39.461699
# 13  1983                          42.780842
# 14  1984                          45.467097
# 15  1985                          48.043183
# 16  1986                          51.495935
# 17  1987                          55.989435
# 18  1988                          59.739879
# 19  1989                          62.461294
# ...

# %%
norway_data.plot(kind ='line',
                 title = 'Norways Consumer vs Wholesale price index',
                x = 'Year',
                y = ['Consumer price index (2010 = 100)','Wholesale price index (2010 = 100)'])
plt.show()

# %%
malaysia_data = pd.read_csv(r'/home/jeromemugita/Downloads/malaysia.csv')
malaysia_data
# Out:
#     Year  Consumer price index (2010 = 100)
# 0   1970                          23.339557  \
# 1   1971                          23.716033
# 2   1972                          24.482429
# 3   1973                          27.067817
# 4   1974                          31.758394
# 5   1975                          33.183622
# 6   1976                          34.057583
# 7   1977                          35.688337
# 8   1978                          37.422813
# 9   1979                          38.790418
# 10  1980                          41.379647
# 11  1981                          45.393472
# 12  1982                          48.034873
# 13  1983                          49.814198
# 14  1984                          51.755593
# 15  1985                          51.934905
# 16  1986                          52.317667
# 17  1987                          52.469392
# 18  1988                          53.810782
# 19  1989                          55.324588
# ...

# %%
malaysia_data.plot(kind ='line',
                    title = 'Malaysia Consumer vs Wholesale price index',
                x = 'Year',
                y = ['Consumer price index (2010 = 100)','Wholesale price index (2010 = 100)'])
plt.show()

# %%
unitedKingdom_data = pd.read_csv(r'/home/jeromemugita/Downloads/unitedkingdom.csv')
unitedKingdom_data
# Out:
#     Year  Consumer price index (2010 = 100)
# 0   1970                          34.678970  \
# 1   1971                          30.801526
# 2   1972                          23.306133
# 3   1973                          24.624772
# 4   1974                          25.166611
# 5   1975                          28.081639
# 6   1976                          27.005577
# 7   1977                          28.179669
# 8   1978                          26.079524
# 9   1979                          22.582210
# 10  1980                          22.027704
# 11  1981                          22.558685
# 12  1982                          25.017103
# 13  1983                          25.706757
# 14  1984                          28.038271
# 15  1985                          27.142128
# 16  1986                          25.144475
# 17  1987                          21.863894
# 18  1988                          55.456068
# 19  1989                          58.360632
# ...

# %%
unitedKingdom_data.plot(kind ='line',
                        title = 'United Kingdom Consumer vs Wholesale price index',
                x = 'Year',
                y = ['Consumer price index (2010 = 100)','Wholesale price index (2010 = 100)'])
plt.show()
